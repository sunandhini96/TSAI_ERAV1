# %% [markdown]
# <a href="https://colab.research.google.com/github/sunandhini96/TSAI_ERAV1/blob/main/Session_21/session_21_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sunandhini96/TSAI_ERAV1.git
# Out:
# Cloning into 'TSAI_ERAV1'...
# remote: Enumerating objects: 914, done.
# remote: Counting objects: 100% (442/442), done.
# remote: Compressing objects: 100% (237/237), done.
# remote: Total 914 (delta 245), reused 341 (delta 194), pack-reused 472
# Receiving objects: 100% (914/914), 28.74 MiB | 29.97 MiB/s, done.
# Resolving deltas: 100% (437/437), done.

# %%
# !pip install torch numpy transformers datasets tiktoken wandb tqdm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 47.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.7/493.7 kB 36.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 98.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 82.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 32.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 32.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 86.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 25.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.2/243.2 kB 27.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
cd /content/TSAI_ERAV1/Session_21
# Out:
# /content/TSAI_ERAV1/Session_21

# %%
# !python data/shakespeare_char/prepare.py
# Out:
# length of dataset in characters: 1,115,394
# all the unique characters:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# vocab size: 65
# train has 1,003,854 tokens
# val has 111,540 tokens

# %%
# import torch._dynamo
# torch._dynamo.config.suppress_errors = True

# %%
# !python train.py config/train_shakespeare_char.py
# Out:
# Overriding config with config/train_shakespeare_char.py:
# # train a miniature character-level shakespeare model
# # good for debugging and playing on macbooks and such
#
# out_dir = 'out-shakespeare-char'
# eval_interval = 250 # keep frequent because we'll overfit
# eval_iters = 200
# log_interval = 10 # don't print too too often
#
# # we expect to overfit on this small dataset, so only save when val improves
# always_save_checkpoint = False
#
# wandb_log = False # override via command line if you like
# wandb_project = 'shakespeare-char'
# wandb_run_name = 'mini-gpt'
#
# dataset = 'shakespeare_char'
# gradient_accumulation_steps = 1
# batch_size = 64
# block_size = 256 # context of up to 256 previous characters
#
# # baby GPT model :)
# n_layer = 6
# n_head = 6
# n_embd = 384
# dropout = 0.2
#
# learning_rate = 1e-3 # with baby networks can afford to go a bit higher
# max_iters = 5000
# lr_decay_iters = 5000 # make equal to max_iters usually
# ...

# %%
# !python sample.py --out_dir=out-shakespeare-char
# Out:
# Overriding: out_dir = out-shakespeare-char
# number of parameters: 10.65M
# Loading meta from data/shakespeare_char/meta.pkl...
#
#
# ANGELO:
# And coward, is not the mistress of tent?
#
# Officer:
# You have been a put of her back: let me saw your honour's wife,
# When I shall find your mildness.
#
# CLIFFORD:
# In mine arms that virtues you look'd in your pelicion,
# That like your loyalty minister.
#
# LORD WILLOUGLEY:
# The gracious mistress that moves so doth prizate,
# Some other she shore strong of her burther.
#
# CLIFFORD:
# And worse must not malice than fair Lady Somerset;
# Let's forbids a hopely have her brothers.
#
# DUKE OF YORK:
# So far for hi
# ---------------
#
# Men pardon, marry: I will give me
# That I have sent forth and madam to my son
# Upon my subjects. I must be patient,
# That I turn and extremity to his pardon
# His strange and designs from my soul son
# To his remedies, his blood, as I know the side he
# ...
